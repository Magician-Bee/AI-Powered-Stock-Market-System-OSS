# %%
import pandas as pd
import requests
from lxml import etree
import json

# %%
df_path = r"C:\Users\your-user\python_projects\FinRL-Meta\FinGPT-ChatGLM-Fineturning_old\Chinese_News\scrape\results\000001.csv"
df = pd.read_csv(df_path)
df.shape

# %%
df.head(2)

# %%
link_base = "https://guba.eastmoney.com"
url = link_base + df.head(1)["content link"][0]
url

# %%
headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/112.0",
        "Referer": "https://guba.eastmoney.com/",
}

# %%
response = requests.get(url = url, headers = headers,)
response.status_code

# %%
res = etree.HTML(response.text)
res = res.xpath("//script[2]//text()")[0]
res = json.loads(res[17:])
res = pd.Series(res).to_frame().T
res
