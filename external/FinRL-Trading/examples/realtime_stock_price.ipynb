# %%
# %cd "../"

# %%
from src.data.data_fetcher import FMPFetcher

fetcher = FMPFetcher()
while True:
    # get real time price data of a batch
    print(fetcher.get_realtime_batch_price_data(['AAPL', 'NVDA']))

    # get real time price data of a single stock
    print(fetcher.get_realtime_single_price_data('AAPL'))
